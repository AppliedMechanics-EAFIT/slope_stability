# %% [markdown]
# # Global equilibrium method
#
# © 2022 Exneyder A. Montoya-Araque, Daniel F. Ruiz and Universidad EAFIT.
#
# This notebook can be interactively run in [Google - Colab](https://colab.research.google.com/github/eamontoyaa/EAFIT_slope_stability/blob/main/notebooks/global_equilibrium_method.ipynb).

# %% [markdown]
# ## Required modules and initial setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from shapely.geometry import Polygon, LineString
from ipywidgets import interact, widgets

plt.style.use("default")
mpl.rcParams.update(
    {
        "text.usetex": False,  # Use mathtext, not LaTeX
        "font.family": "serif",  # Use the Computer modern font
        "font.serif": "cmr10",
        "mathtext.fontset": "cm",
        "axes.formatter.use_mathtext": True,
        "axes.unicode_minus": False
    }
)

# %% [markdown]
# ## Area and centroid of a mass sliding along a circular surface
#
# ### Funtions

# %%
def slope(height, inclination, hzt_dist):
    inclination = np.radians(inclination)
    hzt_slope = height / np.tan(inclination)  # horizontal dist. of slope face
    terrain_coords = np.array(
        (
            (-hzt_dist, 0, hzt_slope, hzt_slope + hzt_dist),
            (0, 0, height, height),
        )
    )
    return terrain_coords


def circular_surface(center_x, center_y, radius, height):
    x_max = np.sqrt(radius**2 - (height - center_y) ** 2) + center_x
    x_min = -np.sqrt(radius**2 - (0 - center_y) ** 2) + center_x
    x = np.linspace(x_min, x_max, 50)
    y = -np.sqrt(radius**2 - (x - center_x) ** 2) + center_y
    slip_surf_coords = np.array((x, y))
    return slip_surf_coords


def get_geometric_parameters(terrain_coords, slip_surf_coords):
    surface_line = LineString(slip_surf_coords.T)
    if slip_surf_coords[0].min() <= 0:
        mass_coords = np.vstack((slip_surf_coords.T, terrain_coords[:, 2:0:-1].T))
    else:
        mass_coords = np.vstack((slip_surf_coords.T, terrain_coords[:, 2]))
    mass_polygon = Polygon(mass_coords)
    return mass_polygon, surface_line


def plot_slope(height, inclination, center_x, center_y, radius):
    slip_surf_coords = circular_surface(center_x, center_y, radius, height)
    hzt_dist = 0.3*height + slip_surf_coords[0].max() - height/np.tan(np.radians(inclination))
    terrain_coords = slope(height, inclination, hzt_dist)
    mass_polygon, surface_line = get_geometric_parameters(
        terrain_coords, slip_surf_coords
    )
    fig, ax = plt.subplots(ncols=1, nrows=1, figsize=[6, 4])
    ax.plot(terrain_coords[0], terrain_coords[1], "k")
    ax.plot(
        slip_surf_coords[0],
        slip_surf_coords[1],
        "#004488",
        ls="--",
        label=f"Slip surface \n- Area: {mass_polygon.area:.2f} m$^2$ \n- Length: {surface_line.length:.2f} m",
    )
    ax.plot(
        center_x,
        center_y,
        color="black",
        marker="x",
        ls="",
        label=f"Center: $x=${center_x:.1f} m, $y=${center_y:.1f} m",
    )
    ax.plot(
        *mass_polygon.centroid.xy,
        color="#BB5566",
        marker="o",
        ls="",
        label=f"Centroid: $x=${mass_polygon.centroid.x:.1f} m, "
        + f"$y=${mass_polygon.centroid.y:.1f} m",
    )
    ax.set(xlabel="$x$ [m]", ylabel="$y$ [m]")
    ax.set_aspect("equal", "box")
    ax.set_ylim((min(slip_surf_coords[1].min()-2, -2), max(center_y+1, height+1)))
    ax.spines["bottom"].set_linewidth(1.5)
    ax.spines["left"].set_linewidth(1.5)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.15))
    fig.tight_layout()
    return

# %% [markdown]
# ### Static figure

# %%
height = 8  # [m]
inclination = 45  # [°]
center_x = 3.5  # [m]
center_y = 12  # [m]
radius = 15  # [m]
plot_slope(height, inclination, center_x, center_y, radius)

# %% [markdown]
# ### Interactive figure

# %%
style = {'description_width': '150px'}
interact(  # Interactive widgets
    plot_slope,
    height=widgets.FloatText(value=8, description="Height [m]", style=style),
    inclination=widgets.FloatText(value=45, description="Inclination [°]", style=style),
    center_x=widgets.FloatText(value=3.5, description="Center abscissa, Cx [m]", style=style),
    center_y=widgets.FloatText(value=11.5, description="Center ordinate, Cy [m]", style=style),
    radius=widgets.FloatText(value=15, description="Radius [m]", style=style)
)
# Out:
# interactive(children=(FloatText(value=8.0, description='Height [m]', style=DescriptionStyle(description_width=…
# <function __main__.plot_slope(height, inclination, center_x, center_y, radius)>
